# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3])

# %%
plt.plot([1,2,3,4],[1,4,2,3])

# %%
fig = plt.figure()
#fig, ax=plt.subplots()
fig, axs =plt.subplots(2,2)

# %% [markdown]
# The data limits can be controlled via the 'axes.Axes.set_xlim()" and "axes.Axes.set_ylim()" methods.
# Each Axes has a title set via "set_title()", an x-label set via"set_xlabel()" and y-label set via "set_ylabel()".

# %%
a = pd.DataFrame(np.random.rand(4,2), columns =list('ab'))
a
# Out:
#           a         b
# 0  0.233971  0.595747
# 1  0.373465  0.084220
# 2  0.689776  0.221392
# 3  0.503401  0.868109

# %%
a_asarray= a.values
a_asarray
# Out:
# array([[0.2339712 , 0.59574679],
#        [0.37346508, 0.08421957],
#        [0.68977585, 0.22139217],
#        [0.50340127, 0.86810945]])

# %%
x = np.linspace(0, 2, 100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
#        1.41414141, 1.43434343, 1.45454545, 1.47474747, 1.49494949,
#        1.51515152, 1.53535354, 1.55555556, 1.57575758, 1.5959596 ,
#        1.61616162, 1.63636364, 1.65656566, 1.67676768, 1.6969697 ,
#        1.71717172, 1.73737374, 1.75757576, 1.77777778, 1.7979798 ,
#        1.81818182, 1.83838384, 1.85858586, 1.87878788, 1.8989899 ,
#        1.91919192, 1.93939394, 1.95959596, 1.97979798, 2.        ])

# %%
# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
a,b,c,d = np.random.randn(4,100)

# %%
fig, (axs1,axs2) = plt.subplots(1,2)
axs1.plot(a,b, label ="ab-plot")
axs2.plot(c,d, label = "cd-plot")

# %%
fig, (axs1,axs2, axs3, axs4) = plt.subplots(1,4)
axs1.plot(a)
axs2.plot(c)
axs3.plot(b)
axs4.plot(d)
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
print(data['c'])
# Out:
# [12 36  0 17 48 14  4 23 25 27 41 29  9 37  6  6 47  9 39 47 47 40 19 44
#  21 30 39 47 42 18 45 43  7 39 46  4 36 48  3  4 30 18 38 11  1  3 13 49
#  46 21]

# %%
print(data['d'])
# Out:
# [122.73578938  70.46904372  22.44373087 120.65348288  31.49847005
#   37.39630292  68.66217835   1.95044586 151.59749423 126.2604664
#  141.29275508  17.48195166 131.18313139 124.00620103  28.26299484
#   17.66757736  50.08178003  90.26830163  81.47133627  12.26964999
#   31.44392278 111.85773186  20.3251776   20.47555696  42.17153246
#  239.57142841  23.7851732  296.43155969  70.04996847  64.37328868
#  142.88290377 110.90478291  91.38651072 108.26780624 199.97689482
#   89.88300941  18.81946159  74.75527131  34.29427896 153.212865
#    1.57934798  12.52093078  90.29792905  32.34138484  93.49753919
#  132.18723949 296.99702413  65.36869738 115.12032211  50.27110297]

# %%
plt.scatter('a', 'b', c='c', s='d',data=data )
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
fig, ax =plt.subplots()
ax.scatter('a','b', c='c', s='d', data=data, )
